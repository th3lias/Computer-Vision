# %% [markdown]
# |First Name     |Last Name    |MtkNr.      |Due Date  |
# |:-------------:|:-----------:|:----------:|:--------:|
# | Elias    | Mindlberger  | 12043382     | 09.12.2024, 16:00

# %% [markdown]
# <h1 style="color:rgb(150,100,10)">Computer Vision Course</h1>
# <h2 style="color:rgb(150,100,10)">Assignment 3 – Optical Flow, Object Tracking and Detection</h2>

# %% [markdown]
# <b>Authors:</b> O. Bimber, M. Abbass<br>
# <b>Date:</b> 25-09-2024
#
# <b>This file is part of the "Computer Vision Course 2024W" UE material.</b>

# %% [markdown]
# <h2 style="color:rgb(150,100,10)">Table of Contents</h2>
# <ol>
#     <a style="color:rgb(150,100,10)" href="#Optical-Flow"><li style="font-size:large;font-weight:bold">Optical Flow</li></a>
#     <ol style="margin-bottom:15px">
#         <a style="color:rgb(150,100,10)" href="#Apply-Lucas-Kanade"><li style="font-size:medium">Apply Lucas-Kanade</li></a>
#         <a style="color:rgb(150,100,10)" href="#Apply-Farneback"><li style="font-size:medium">Apply Farneback Optical Flow</li></a>
# </ol>
#     <a style="color:rgb(150,100,10)" href="#Object-Tracking"><li style="font-size:large;font-weight:bold">Object Tracking</li></a>
#     <ol style="margin-bottom:15px">
#         <a style="color:rgb(150,100,10)" href="#Apply-Yolov8-for-object-tracking"><li style="font-size:medium">Apply Yolov8 for object tracking</li></a>
# </ol></a>
#     </ol>
# </ol>

# %% [markdown]
# <h1 style="color:rgb(255,0,0)">Important Note</h1>
#
# <b>In this assignment, you can use the default parameters in any built-in function unless specified otherwise.</b>
#
# <b>All cells must be evaluated, and any unevaluated cell may lead to a loss of points, regardless of the correctness of the code.</b>
#
# <b>If you have GPU resources available on your machine, please utilize them; otherwise, you can use your CPU.</b>

# %%
# Import all packages needed in this notebook.
import numpy as np
import cv2 as cv
from PIL import Image
from matplotlib import pyplot as plt
import os
import glob
from scipy import signal
import shutil

if not os.path.exists('resources'): raise TypeError("Please create the resources folder and include all required stuff")

# %% [markdown]
# <a name="Optical-Flow"></a><h2> Optical Flow</h2>
#
# The main goal is to utilize optical flow to track object features. Two general optical flow approaches exist: Sparse Optical Flow (e.g., <i><b>the Lucas-Kanade method</b></i>) and Dense Optical Flow (e.g., <i><b>the Farneback method</b></i>).

# %% [markdown]
# <a name="Apply-Lucas-Kanade"></a><h3>Apply Lucas-Kanade</h3>

# %% [markdown]
# <b>Exercise 1.1. [20 Points]</b>
#
# <b>Goal:</b> The aim here is to apply the <i><b>Lucas-Kanade Method</b></i>.
#
# <b>Task</b>
# <ul>
# <li>Complete the function <i><b>sparse_optical</b></i> below to compute sparse optical flow</li>
# <li>The <i><b>Lucas-Kanade Method</b></i> can be used from the OpenCV library.</li>
# <li>The parameters of the <i><b>Lucas-Kanade Method</b></i> are as follows:
# <ol>
#   <li>Use the <i><b>good_Feture</b></i> variable as an input flow vector</li>
#   <li>Size of the search window at each pyramid level = 15</li>
#   <li>Maximal pyramid level number = 2</li>
#   <li>Criteria = 10, 0.03</li>
#   <li>output vector = <i><b>None</b></i></li>
#   <li>output status vector = <i><b>None</b></i></li>
#   <li>output vector of errors = <i><b>None</b></i></li>
# </ol>
#
#
# </ul>
#
# <b>Hint</b>
# <ul>
# <li>The function <i><b>sparse_optical</b></i> uses the video <i><b>vtest.avi</b></i></li>
# <li>The video <i><b>vtest.avi</b></i> is in the <i><b>resources</b></i> folder. <i><b>Therefore, you must make sure to include this video.</b></i>.</li>
#
# </ul>

# %%
def sparse_optical(path_Video):
    cap = cv.VideoCapture(cv.samples.findFile(path_Video))
    no_Frames = int(cap.get(cv.CAP_PROP_FRAME_COUNT))
    print( 'Total number of frames is' , no_Frames )
 
    feature_params = dict( maxCorners = 100, qualityLevel = 0.3, minDistance = 7, blockSize = 7 )
    color = np.random.randint(0, 255, (100, 3))

    ret, old_frame = cap.read()
    prevImg = cv.cvtColor(old_frame, cv.COLOR_BGR2GRAY)
    good_Feture = cv.goodFeaturesToTrack(prevImg, mask = None, **feature_params)
    mask = np.zeros_like(old_frame)
    dt = 100
    while(1):
        ret, frame = cap.read()
        if not ret:
            print('No frames grabbed!')
            break

        nextImg = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)

        # code goes here
        lk_params = dict(winSize  = (15, 15),
                         maxLevel = 2,
                         criteria = (cv.TERM_CRITERIA_EPS | cv.TERM_CRITERIA_COUNT, 10, 0.03))
        p1, st, err = cv.calcOpticalFlowPyrLK(prevImg, nextImg, good_Feture, None, **lk_params)

        if p1 is not None:
            good_new = p1[st==1]
            good_old = good_Feture[st==1]

        for i, (new, old) in enumerate(zip(good_new, good_old)):
            a, b = np.ravel(old)
            c, d = np.ravel(new)
            v_x = int((c - a)/dt)
            v_y = int((b - d)/dt)
            scale = 100
            v_x = int((c-a)/dt*scale)
            v_y = int((b-d)/dt*scale)

            mask = cv.arrowedLine(mask, (int(a),int(b)), (int(a)+v_x, int(b)+v_y), (255, 255, 255), 1)
        img = cv.add(frame, mask)

        cv.imshow('Result sparse optical flow', img)
        k = cv.waitKey(30) & 0xff
        if k == 27:
            break

        prevImg = nextImg.copy()
        good_Feture = good_new.reshape(-1, 1, 2)

    cv.destroyAllWindows()

sparse_optical("resources/vtest.avi")
cv.waitKey(1)
# Out:
# Total number of frames is 795
# 2024-12-03 08:57:04.779 Python[63754:2662427] +[IMKClient subclass]: chose IMKClient_Modern
# 2024-12-03 08:57:04.779 Python[63754:2662427] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# No frames grabbed!
# -1

# %% [markdown]
# <h1 style="color:rgb(150,77,0)">Note about the output visualization</h1>
#
# Now, let's use Dense Optical Flow. We will be utilizing the <i><b>Farneback Method</b></i>, one of the most popular implementations of Dense Optical Flow.
#
# Dense Optical Flow computes the optical flow vector for every pixel in each frame, representing both the direction and magnitude for each pixel.
#
# Since Dense Optical Flow provides a denser result, we use color coding for <i><b>better visualization</b></i>. We utilize <i><b>HSV planes</b></i> to display the results of Dense Optical Flow: the direction corresponds to the <i><b>Hue value</b></i> of the image, while the magnitude corresponds to the <i><b>Value plane</b></i>.

# %% [markdown]
# <a name="Apply-Farneback"></a><h3>Apply Farneback Optical Flow</h3>

# %% [markdown]
# <b>Exercise 1.2. [20 Points]</b>
#
# <b>Goal:</b> The aim here is to apply the <i><b>Farneback Method</b></i>.
#
# <b>Task</b>
# <ul>
# <li>Complete the function <i><b>dense_optical</b></i> below to compute dense optical flow.</li>
# <li>The <i><b>Farneback Method</b></i> can be used from the OpenCV library.</li>
# <li>The parameters of the <i><b>Farneback Method</b></i> are as follows:
# <ol>
#   <li>parameters for computing the flow including the previous flow = None</li>
#   <li>image scale for pyramid construction = 0.5</li>
#   <li>number of pyramid layers = 3</li>
#   <li>window size = 15</li>
#  <li>number of iterations at each pyramid level = 3</li>
#  <li>size of the pixel neighborhood for polynomial expansion = 5</li>
#  <li>The standard deviation of the Gaussian = 1.2</li>
#   <li>operation flags = 0</li>
# </ol>
#
# </ul>
#
# <b>Hint</b>
# <ul>
# <li>In the same manner, the function <i><b>dense_optical</b></i> uses the video <i><b>vtest.avi</b></i></li>
# <li>Again, the video <i><b>vtest.avi</b></i> is in the <i><b>resources</b></i> folder. <i><b>Therefore, you must make sure to include this video</b></i>.</li>
# </ul>

# %%
def dense_optical(path_Video):
    
    cap = cv.VideoCapture(cv.samples.findFile(path_Video))
    no_Frames = int(cap.get(cv.CAP_PROP_FRAME_COUNT))
    print( 'Total number of frames is' , no_Frames )
    
    ret, prvs_frame1 = cap.read()
    prvs_frame = cv.cvtColor(prvs_frame1, cv.COLOR_BGR2GRAY)
    hsv = np.zeros_like(prvs_frame1)
    hsv[..., 1] = 255

    while(1):
        ret, next_frame2 = cap.read()
        frame_copy = next_frame2
        if not ret:
            print('No frames grabbed!')
            break
        next_frame = cv.cvtColor(next_frame2, cv.COLOR_BGR2GRAY)

        # The code goes here
        flow = cv.calcOpticalFlowFarneback(prvs_frame, next_frame, None, 0.5, 3, 15, 3, 5, 1.2, 0)

        mag, ang = cv.cartToPolar(flow[..., 0], flow[..., 1])
        hsv[..., 0] = ang*180/np.pi/2
        hsv[..., 2] = cv.normalize(mag, None, 0, 255, cv.NORM_MINMAX)
        bgr = cv.cvtColor(hsv, cv.COLOR_HSV2BGR)
        
        img = cv.add(next_frame2, bgr)
        cv.imshow('Result dense optical flow', img)        

        
        k = cv.waitKey(30) & 0xff
        if k == 27:
            break
            
        prvs_frame = next_frame
    cap.release()
    cv.destroyAllWindows()

dense_optical("resources/vtest.avi")
cv.waitKey(1)
# Out:
# Total number of frames is 795
# No frames grabbed!
# -1

# %% [markdown]
# <b>Exercise 1.3. [20 Points]</b>
#
# <b>Question</b>
# <ul>
# <li>Dense optical flow methods, such as Farneback, provide flow vectors for each pixel. Why should we still use sparse optical flow methods, such as Lucas-Kanade? What are the advantages of sparse optical flow over dense optical flow?</li>
# </ul>

# %% [markdown]
# The explanation goes here:

# %% [markdown]
# Sparse optical flow, like Lucas-Kanade, tracks only specific, important points (e.g., corners or edges) instead of every pixel, making it faster and less computationally heavy than dense methods like Farneback. It is especially useful when the motion in the scene is subtle or when processing power is limited. Sparse methods also tend to be more robust to noise because they focus on well-defined features instead of entire image regions. However, they may miss motion in less textured areas of the image.

# %% [markdown]
# <a name="Object-Tracking"></a><h2> Object Tracking</h2>
#
# In the second part, we utilize the most popular technique in image tracking: <i><b>YOLOv8</b><i><i>.
#
# <span style="color:rgb(200,100,10)">More details can be found at [this link](https://docs.ultralytics.com/modes/track/)</span>.
#
# <b>As we did in assignment 2, let's complete a couple of steps as follows:</b>
# <ul>
# <li>We need to install the <i><b>ultralytics</b></i> package using this command: <i><b>pip install ultralytics</b>.</i>
# <li>We need to import YOLO.</i>
# </li>

# %%
from ultralytics import YOLO

# %% [markdown]
# <a name=">Apply-Yolov8-for-object-tracking"></a><h3>Apply Yolov8 for object tracking</h3>

# %% [markdown]
# <b>Exercise 2.1. [20 Points]</b>
#
# <b>Goal:</b> Let's apply the most popular tracker which is <i><b>YOLOv8</b></i>.
#
# <b>Task</b>
# <ul>
# <li>Complete the function <i><b>yolo_Track</b></i> below to apply the object tracking using <i><b>YOLOv8</b></i>.</li>
# <li>The parameters of the <i><b>YOLO tracker</b></i> are as follows:
# <ol>
#   <li>persist = True</li>
# </ol>
# </ul>
#
# <b>Hint</b>
# <ul>
# <li>The pre-trained model <i><b>yolov8n.pt</b></i> is utilized in this assignment.</li>
# <li>In the same manner, the function <i><b>yolo_Track</b></i> uses the video <i><b>vtest.avi</b></i></li>
# <li>Again, the video <i><b>vtest.avi</b></i> is in the <i><b>resources</b></i> folder. <i><b>Therefore, you must make sure to include this video</b></i>.</li>
# </ul>

# %%
# YOLO TRACKING
def yolo_Track(video_path, inter_Frame=5):
    model = YOLO("yolov8n.pt")
            
    cap = cv.VideoCapture(video_path)
    no_Frames = int(cap.get(cv.CAP_PROP_FRAME_COUNT))
    print( 'Total number of frames is' , no_Frames )
    
    while(1):
        ret, frame = cap.read()
        if not ret:
            print('No frames grabbed!')
            break
        
        # The code goes here
        results = model.track(frame, persist=True)

        frame_ = results[0].plot()
        
        cv.imshow('Result YOLO frame', frame_)

                        
        k = cv.waitKey(30) & 0xff
        if k == 27:
            break

    cap.release()
    cv.destroyAllWindows()

yolo_Track("resources/vtest.avi")
cv.waitKey(1)
# Out:
# Total number of frames is 795
#
# 0: 480x640 3 persons, 1 car, 1 truck, 1 bird, 42.2ms
# Speed: 1.4ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 truck, 1 bird, 32.7ms
# Speed: 1.3ms preprocess, 32.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 truck, 1 bird, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 truck, 1 bird, 31.3ms
# Speed: 1.2ms preprocess, 31.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 truck, 1 bird, 34.0ms
# Speed: 1.1ms preprocess, 34.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 truck, 1 bird, 33.1ms
# Speed: 1.2ms preprocess, 33.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 truck, 1 bird, 33.9ms
# Speed: 1.1ms preprocess, 33.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 truck, 1 bird, 38.5ms
# Speed: 1.2ms preprocess, 38.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 truck, 1 bird, 40.5ms
# Speed: 1.4ms preprocess, 40.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 truck, 1 bird, 34.8ms
# Speed: 1.0ms preprocess, 34.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 truck, 1 bird, 34.8ms
# Speed: 1.1ms preprocess, 34.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 37.4ms
# Speed: 1.9ms preprocess, 37.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 32.8ms
# Speed: 1.3ms preprocess, 32.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 34.8ms
# Speed: 1.1ms preprocess, 34.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 34.3ms
# Speed: 1.0ms preprocess, 34.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 35.1ms
# Speed: 1.1ms preprocess, 35.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 39.4ms
# Speed: 1.1ms preprocess, 39.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 33.3ms
# Speed: 1.3ms preprocess, 33.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 30.3ms
# Speed: 1.2ms preprocess, 30.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 30.8ms
# Speed: 1.0ms preprocess, 30.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 29.7ms
# Speed: 1.1ms preprocess, 29.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 30.3ms
# Speed: 1.3ms preprocess, 30.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 30.5ms
# Speed: 1.1ms preprocess, 30.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 29.6ms
# Speed: 1.0ms preprocess, 29.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 30.9ms
# Speed: 1.5ms preprocess, 30.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 30.3ms
# Speed: 1.0ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 32.9ms
# Speed: 1.2ms preprocess, 32.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 28.7ms
# Speed: 1.3ms preprocess, 28.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 29.6ms
# Speed: 1.1ms preprocess, 29.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 truck, 1 bird, 30.2ms
# Speed: 1.1ms preprocess, 30.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 truck, 1 bird, 28.6ms
# Speed: 1.2ms preprocess, 28.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 truck, 1 bird, 29.9ms
# Speed: 1.0ms preprocess, 29.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 31.5ms
# Speed: 1.2ms preprocess, 31.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 29.1ms
# Speed: 1.1ms preprocess, 29.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 30.4ms
# Speed: 1.3ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 29.8ms
# Speed: 1.0ms preprocess, 29.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 29.6ms
# Speed: 1.2ms preprocess, 29.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 29.8ms
# Speed: 1.0ms preprocess, 29.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.8ms
# Speed: 1.1ms preprocess, 30.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 31.1ms
# Speed: 1.2ms preprocess, 31.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 31.3ms
# Speed: 1.1ms preprocess, 31.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.3ms
# Speed: 1.1ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.5ms
# Speed: 1.0ms preprocess, 29.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.0ms
# Speed: 1.2ms preprocess, 30.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.6ms
# Speed: 1.0ms preprocess, 30.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 28.9ms
# Speed: 1.1ms preprocess, 28.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 29.4ms
# Speed: 1.2ms preprocess, 29.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 39.2ms
# Speed: 1.2ms preprocess, 39.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 29.8ms
# Speed: 1.2ms preprocess, 29.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 30.8ms
# Speed: 1.0ms preprocess, 30.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 34.9ms
# Speed: 1.2ms preprocess, 34.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 33.7ms
# Speed: 1.3ms preprocess, 33.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 35.8ms
# Speed: 1.1ms preprocess, 35.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 car, 1 truck, 1 bird, 30.4ms
# Speed: 1.1ms preprocess, 30.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 30.7ms
# Speed: 1.3ms preprocess, 30.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 29.6ms
# Speed: 1.1ms preprocess, 29.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.5ms
# Speed: 1.1ms preprocess, 29.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.1ms
# Speed: 1.0ms preprocess, 29.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.4ms
# Speed: 1.3ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.4ms
# Speed: 1.1ms preprocess, 29.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.4ms
# Speed: 1.1ms preprocess, 29.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.6ms
# Speed: 1.0ms preprocess, 30.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 31.0ms
# Speed: 1.3ms preprocess, 31.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.7ms
# Speed: 1.1ms preprocess, 29.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.1ms
# Speed: 1.1ms preprocess, 30.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 31.3ms
# Speed: 1.2ms preprocess, 31.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 30.2ms
# Speed: 1.0ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 30.4ms
# Speed: 1.1ms preprocess, 30.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 34.1ms
# Speed: 1.2ms preprocess, 34.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 33.6ms
# Speed: 1.3ms preprocess, 33.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 36.0ms
# Speed: 1.1ms preprocess, 36.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 35.1ms
# Speed: 1.0ms preprocess, 35.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 30.2ms
# Speed: 1.2ms preprocess, 30.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 30.2ms
# Speed: 1.0ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.4ms
# Speed: 1.1ms preprocess, 30.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 34.5ms
# Speed: 1.1ms preprocess, 34.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 35.1ms
# Speed: 2.0ms preprocess, 35.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.3ms
# Speed: 1.1ms preprocess, 30.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.8ms
# Speed: 1.2ms preprocess, 30.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.7ms
# Speed: 1.1ms preprocess, 30.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.2ms
# Speed: 1.1ms preprocess, 29.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.8ms
# Speed: 1.1ms preprocess, 29.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 31.6ms
# Speed: 1.1ms preprocess, 31.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.9ms
# Speed: 1.1ms preprocess, 29.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.6ms
# Speed: 1.1ms preprocess, 30.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.7ms
# Speed: 1.0ms preprocess, 30.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.6ms
# Speed: 1.0ms preprocess, 29.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.9ms
# Speed: 1.2ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.2ms
# Speed: 1.1ms preprocess, 29.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 33.3ms
# Speed: 1.0ms preprocess, 33.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 31.1ms
# Speed: 1.2ms preprocess, 31.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.6ms
# Speed: 1.0ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.4ms
# Speed: 1.1ms preprocess, 29.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.3ms
# Speed: 1.3ms preprocess, 29.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.7ms
# Speed: 1.0ms preprocess, 29.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.5ms
# Speed: 1.2ms preprocess, 30.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.3ms
# Speed: 1.4ms preprocess, 30.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.7ms
# Speed: 1.1ms preprocess, 29.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 37.4ms
# Speed: 1.2ms preprocess, 37.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 29.4ms
# Speed: 1.1ms preprocess, 29.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 28.4ms
# Speed: 1.0ms preprocess, 28.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.9ms
# Speed: 1.2ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.3ms
# Speed: 1.1ms preprocess, 29.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 28.8ms
# Speed: 1.1ms preprocess, 28.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 29.3ms
# Speed: 1.2ms preprocess, 29.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 30.5ms
# Speed: 1.1ms preprocess, 30.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 37.2ms
# Speed: 1.2ms preprocess, 37.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.4ms
# Speed: 1.2ms preprocess, 29.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.7ms
# Speed: 1.1ms preprocess, 29.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 28.5ms
# Speed: 1.3ms preprocess, 28.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.8ms
# Speed: 1.1ms preprocess, 29.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 28.5ms
# Speed: 1.1ms preprocess, 28.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.2ms
# Speed: 1.1ms preprocess, 29.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.6ms
# Speed: 1.0ms preprocess, 29.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.6ms
# Speed: 1.1ms preprocess, 29.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.6ms
# Speed: 1.1ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 30.2ms
# Speed: 1.1ms preprocess, 30.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 30.2ms
# Speed: 1.1ms preprocess, 30.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 30.0ms
# Speed: 1.2ms preprocess, 30.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 28.2ms
# Speed: 1.1ms preprocess, 28.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 28.8ms
# Speed: 1.0ms preprocess, 28.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 31.0ms
# Speed: 1.1ms preprocess, 31.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 31.7ms
# Speed: 1.1ms preprocess, 31.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 31.9ms
# Speed: 1.1ms preprocess, 31.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.9ms
# Speed: 1.1ms preprocess, 29.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 28.8ms
# Speed: 1.0ms preprocess, 28.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.6ms
# Speed: 1.1ms preprocess, 29.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 29.4ms
# Speed: 1.0ms preprocess, 29.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 29.6ms
# Speed: 1.1ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 28.7ms
# Speed: 1.1ms preprocess, 28.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 30.4ms
# Speed: 1.1ms preprocess, 30.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 29.6ms
# Speed: 1.0ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 45.4ms
# Speed: 1.3ms preprocess, 45.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 28.3ms
# Speed: 1.3ms preprocess, 28.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 1 car, 1 truck, 28.9ms
# Speed: 1.1ms preprocess, 28.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 1 car, 1 truck, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 1 car, 1 truck, 29.0ms
# Speed: 1.2ms preprocess, 29.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 1 car, 1 truck, 28.6ms
# Speed: 1.1ms preprocess, 28.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 1 car, 1 truck, 27.9ms
# Speed: 1.2ms preprocess, 27.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 1 car, 1 truck, 29.5ms
# Speed: 1.0ms preprocess, 29.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 1 car, 1 truck, 28.8ms
# Speed: 1.0ms preprocess, 28.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 1 car, 1 truck, 29.7ms
# Speed: 1.3ms preprocess, 29.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 1 car, 1 truck, 28.7ms
# Speed: 1.1ms preprocess, 28.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 1 car, 1 truck, 1 bird, 30.1ms
# Speed: 1.1ms preprocess, 30.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 1 car, 1 truck, 29.2ms
# Speed: 1.0ms preprocess, 29.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 1 car, 1 truck, 28.6ms
# Speed: 1.0ms preprocess, 28.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.3ms
# Speed: 1.1ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 29.6ms
# Speed: 1.1ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 29.6ms
# Speed: 1.0ms preprocess, 29.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 29.4ms
# Speed: 1.1ms preprocess, 29.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 29.3ms
# Speed: 1.3ms preprocess, 29.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 29.5ms
# Speed: 1.0ms preprocess, 29.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 29.1ms
# Speed: 1.2ms preprocess, 29.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 29.1ms
# Speed: 1.1ms preprocess, 29.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 29.9ms
# Speed: 1.3ms preprocess, 29.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 30.1ms
# Speed: 1.3ms preprocess, 30.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.2ms
# Speed: 1.2ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 31.7ms
# Speed: 1.0ms preprocess, 31.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 29.5ms
# Speed: 1.3ms preprocess, 29.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 29.1ms
# Speed: 1.2ms preprocess, 29.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 1 car, 1 truck, 29.9ms
# Speed: 1.3ms preprocess, 29.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 29.6ms
# Speed: 1.0ms preprocess, 29.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 29.7ms
# Speed: 1.1ms preprocess, 29.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 1 car, 1 truck, 28.7ms
# Speed: 1.2ms preprocess, 28.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 1 car, 1 truck, 29.3ms
# Speed: 1.1ms preprocess, 29.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 1 car, 1 truck, 29.3ms
# Speed: 1.1ms preprocess, 29.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 1 car, 1 truck, 29.0ms
# Speed: 1.0ms preprocess, 29.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 29.8ms
# Speed: 1.3ms preprocess, 29.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 37.5ms
# Speed: 1.1ms preprocess, 37.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 35.0ms
# Speed: 1.3ms preprocess, 35.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 35.7ms
# Speed: 1.2ms preprocess, 35.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 36.4ms
# Speed: 1.2ms preprocess, 36.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 32.2ms
# Speed: 1.1ms preprocess, 32.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.1ms
# Speed: 1.2ms preprocess, 29.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 30.9ms
# Speed: 1.3ms preprocess, 30.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 30.2ms
# Speed: 1.1ms preprocess, 30.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.7ms
# Speed: 1.0ms preprocess, 29.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.2ms
# Speed: 1.3ms preprocess, 29.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 32.0ms
# Speed: 1.3ms preprocess, 32.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 34.2ms
# Speed: 1.1ms preprocess, 34.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 34.6ms
# Speed: 1.5ms preprocess, 34.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.7ms
# Speed: 1.1ms preprocess, 30.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.6ms
# Speed: 1.1ms preprocess, 30.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 30.6ms
# Speed: 1.3ms preprocess, 30.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.6ms
# Speed: 1.0ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 30.3ms
# Speed: 1.2ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 31.0ms
# Speed: 1.1ms preprocess, 31.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 31.4ms
# Speed: 1.1ms preprocess, 31.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 31.0ms
# Speed: 1.1ms preprocess, 31.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 29.9ms
# Speed: 1.1ms preprocess, 29.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 34.4ms
# Speed: 1.1ms preprocess, 34.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 33.5ms
# Speed: 1.1ms preprocess, 33.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 29.9ms
# Speed: 1.4ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 31.1ms
# Speed: 1.2ms preprocess, 31.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 30.2ms
# Speed: 1.0ms preprocess, 30.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 29.8ms
# Speed: 1.1ms preprocess, 29.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 30.4ms
# Speed: 1.2ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 30.3ms
# Speed: 1.1ms preprocess, 30.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 34.1ms
# Speed: 1.1ms preprocess, 34.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 36.5ms
# Speed: 1.1ms preprocess, 36.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 36.6ms
# Speed: 1.7ms preprocess, 36.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 31.3ms
# Speed: 1.2ms preprocess, 31.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 28.9ms
# Speed: 1.3ms preprocess, 28.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 29.7ms
# Speed: 1.3ms preprocess, 29.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 29.8ms
# Speed: 1.1ms preprocess, 29.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 29.4ms
# Speed: 1.3ms preprocess, 29.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 28.4ms
# Speed: 1.0ms preprocess, 28.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 skis, 29.1ms
# Speed: 1.1ms preprocess, 29.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 30.4ms
# Speed: 1.1ms preprocess, 30.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 28.9ms
# Speed: 1.2ms preprocess, 28.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 29.3ms
# Speed: 1.0ms preprocess, 29.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 29.7ms
# Speed: 1.2ms preprocess, 29.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 32.7ms
# Speed: 1.1ms preprocess, 32.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 39.9ms
# Speed: 1.1ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 29.5ms
# Speed: 1.3ms preprocess, 29.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 31.5ms
# Speed: 1.1ms preprocess, 31.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 30.5ms
# Speed: 1.2ms preprocess, 30.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 30.2ms
# Speed: 1.0ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 28.2ms
# Speed: 1.0ms preprocess, 28.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 44.8ms
# Speed: 1.1ms preprocess, 44.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.2ms
# Speed: 1.1ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.2ms
# Speed: 1.1ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.1ms
# Speed: 1.1ms preprocess, 30.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 29.3ms
# Speed: 1.0ms preprocess, 29.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 29.4ms
# Speed: 1.3ms preprocess, 29.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.0ms
# Speed: 1.2ms preprocess, 30.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 31.0ms
# Speed: 1.1ms preprocess, 31.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.1ms
# Speed: 1.1ms preprocess, 30.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 28.2ms
# Speed: 1.1ms preprocess, 28.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.1ms
# Speed: 1.1ms preprocess, 30.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 29.5ms
# Speed: 1.1ms preprocess, 29.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.3ms
# Speed: 1.1ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.6ms
# Speed: 1.2ms preprocess, 30.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 31.6ms
# Speed: 1.1ms preprocess, 31.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 31.2ms
# Speed: 1.0ms preprocess, 31.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.3ms
# Speed: 1.1ms preprocess, 30.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 29.9ms
# Speed: 1.1ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.1ms
# Speed: 1.1ms preprocess, 30.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 29.4ms
# Speed: 1.1ms preprocess, 29.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.9ms
# Speed: 1.3ms preprocess, 30.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 29.6ms
# Speed: 1.2ms preprocess, 29.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 kite, 29.8ms
# Speed: 1.0ms preprocess, 29.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 kite, 29.9ms
# Speed: 1.3ms preprocess, 29.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 kite, 29.7ms
# Speed: 1.0ms preprocess, 29.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 kite, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 kite, 28.5ms
# Speed: 1.0ms preprocess, 28.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 kite, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 kite, 29.5ms
# Speed: 1.1ms preprocess, 29.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 kite, 29.5ms
# Speed: 1.0ms preprocess, 29.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 kite, 29.7ms
# Speed: 1.1ms preprocess, 29.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 29.5ms
# Speed: 1.0ms preprocess, 29.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 29.7ms
# Speed: 1.3ms preprocess, 29.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.1ms
# Speed: 1.1ms preprocess, 30.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.8ms
# Speed: 1.6ms preprocess, 30.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.4ms
# Speed: 1.1ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 31.9ms
# Speed: 1.4ms preprocess, 31.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 31.0ms
# Speed: 1.1ms preprocess, 31.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.7ms
# Speed: 1.3ms preprocess, 30.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 57.9ms
# Speed: 2.4ms preprocess, 57.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 34.6ms
# Speed: 1.5ms preprocess, 34.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 37.4ms
# Speed: 1.1ms preprocess, 37.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 35.6ms
# Speed: 1.2ms preprocess, 35.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 31.2ms
# Speed: 1.1ms preprocess, 31.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.1ms
# Speed: 1.2ms preprocess, 30.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 30.5ms
# Speed: 1.1ms preprocess, 30.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 29.9ms
# Speed: 1.1ms preprocess, 29.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 1 car, 1 truck, 34.0ms
# Speed: 1.4ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 33.1ms
# Speed: 1.1ms preprocess, 33.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 32.0ms
# Speed: 1.3ms preprocess, 32.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 29.2ms
# Speed: 1.0ms preprocess, 29.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 31.0ms
# Speed: 1.1ms preprocess, 31.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 31.4ms
# Speed: 1.1ms preprocess, 31.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 30.9ms
# Speed: 1.2ms preprocess, 30.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 29.3ms
# Speed: 1.3ms preprocess, 29.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 31.7ms
# Speed: 1.1ms preprocess, 31.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 31.6ms
# Speed: 1.4ms preprocess, 31.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 31.0ms
# Speed: 1.1ms preprocess, 31.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 30.9ms
# Speed: 1.0ms preprocess, 30.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 35.3ms
# Speed: 1.1ms preprocess, 35.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 40.4ms
# Speed: 1.1ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 37.2ms
# Speed: 1.5ms preprocess, 37.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 36.3ms
# Speed: 1.3ms preprocess, 36.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 36.0ms
# Speed: 1.3ms preprocess, 36.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 32.2ms
# Speed: 1.2ms preprocess, 32.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 31.3ms
# Speed: 1.3ms preprocess, 31.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 34.7ms
# Speed: 1.2ms preprocess, 34.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 33.3ms
# Speed: 1.3ms preprocess, 33.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 35.2ms
# Speed: 1.3ms preprocess, 35.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 30.1ms
# Speed: 1.3ms preprocess, 30.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 30.7ms
# Speed: 1.3ms preprocess, 30.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 31.8ms
# Speed: 1.1ms preprocess, 31.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 30.8ms
# Speed: 1.0ms preprocess, 30.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 31.9ms
# Speed: 1.2ms preprocess, 31.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 33.7ms
# Speed: 1.2ms preprocess, 33.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 39.9ms
# Speed: 1.1ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 31.9ms
# Speed: 1.1ms preprocess, 31.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 31.2ms
# Speed: 1.1ms preprocess, 31.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 32.6ms
# Speed: 1.2ms preprocess, 32.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 30.2ms
# Speed: 1.2ms preprocess, 30.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 31.6ms
# Speed: 1.1ms preprocess, 31.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 31.4ms
# Speed: 1.3ms preprocess, 31.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 29.8ms
# Speed: 1.3ms preprocess, 29.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 33.7ms
# Speed: 1.1ms preprocess, 33.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 31.2ms
# Speed: 1.2ms preprocess, 31.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 31.1ms
# Speed: 1.1ms preprocess, 31.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 30.2ms
# Speed: 1.1ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 car, 1 truck, 1 bird, 29.7ms
# Speed: 1.1ms preprocess, 29.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 28.8ms
# Speed: 1.1ms preprocess, 28.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.8ms
# Speed: 1.0ms preprocess, 30.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.7ms
# Speed: 1.3ms preprocess, 29.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.5ms
# Speed: 1.1ms preprocess, 30.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
# Speed: 1.3ms preprocess, 30.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 2 trucks, 1 bird, 1 kite, 29.9ms
# Speed: 1.0ms preprocess, 29.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 2 trucks, 1 bird, 1 kite, 31.1ms
# Speed: 1.1ms preprocess, 31.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 1 kite, 28.5ms
# Speed: 1.3ms preprocess, 28.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 1 kite, 36.2ms
# Speed: 1.0ms preprocess, 36.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 1 kite, 30.1ms
# Speed: 1.1ms preprocess, 30.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 1 kite, 30.4ms
# Speed: 1.1ms preprocess, 30.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 1 kite, 30.8ms
# Speed: 1.0ms preprocess, 30.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 1 kite, 30.8ms
# Speed: 1.0ms preprocess, 30.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 30.2ms
# Speed: 1.1ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 29.6ms
# Speed: 1.3ms preprocess, 29.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 32.4ms
# Speed: 1.1ms preprocess, 32.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 1 car, 1 truck, 1 bird, 32.2ms
# Speed: 1.2ms preprocess, 32.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 1 car, 1 truck, 1 bird, 30.5ms
# Speed: 1.3ms preprocess, 30.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 1 car, 1 truck, 1 bird, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 29.0ms
# Speed: 1.1ms preprocess, 29.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 29.7ms
# Speed: 1.1ms preprocess, 29.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 30.1ms
# Speed: 1.1ms preprocess, 30.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 30.8ms
# Speed: 1.0ms preprocess, 30.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.7ms
# Speed: 1.1ms preprocess, 29.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.7ms
# Speed: 1.1ms preprocess, 29.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.1ms
# Speed: 1.5ms preprocess, 29.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 30.5ms
# Speed: 1.1ms preprocess, 30.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 35.1ms
# Speed: 1.6ms preprocess, 35.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 30.4ms
# Speed: 1.2ms preprocess, 30.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 30.8ms
# Speed: 1.1ms preprocess, 30.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 30.0ms
# Speed: 1.2ms preprocess, 30.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 29.7ms
# Speed: 1.0ms preprocess, 29.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 30.1ms
# Speed: 1.1ms preprocess, 30.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 29.6ms
# Speed: 1.1ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 29.4ms
# Speed: 1.2ms preprocess, 29.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 29.0ms
# Speed: 1.1ms preprocess, 29.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 30.2ms
# Speed: 1.0ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 28.5ms
# Speed: 1.2ms preprocess, 28.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 30.7ms
# Speed: 1.1ms preprocess, 30.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 29.0ms
# Speed: 1.1ms preprocess, 29.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 bird, 30.1ms
# Speed: 1.1ms preprocess, 30.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 28.8ms
# Speed: 1.3ms preprocess, 28.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 kite, 31.3ms
# Speed: 1.6ms preprocess, 31.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 30.4ms
# Speed: 1.1ms preprocess, 30.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 30.2ms
# Speed: 1.1ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 29.1ms
# Speed: 1.1ms preprocess, 29.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 29.2ms
# Speed: 1.1ms preprocess, 29.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 33.9ms
# Speed: 1.1ms preprocess, 33.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 30.1ms
# Speed: 1.1ms preprocess, 30.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 30.7ms
# Speed: 1.2ms preprocess, 30.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 cars, 1 truck, 1 kite, 30.2ms
# Speed: 1.3ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 30.4ms
# Speed: 1.1ms preprocess, 30.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 29.4ms
# Speed: 1.1ms preprocess, 29.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 29.4ms
# Speed: 1.1ms preprocess, 29.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 32.2ms
# Speed: 1.1ms preprocess, 32.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 car, 1 truck, 1 kite, 30.2ms
# Speed: 1.3ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 kite, 28.9ms
# Speed: 1.1ms preprocess, 28.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 kite, 30.4ms
# Speed: 1.4ms preprocess, 30.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.2ms
# Speed: 1.3ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 1 truck, 1 bird, 30.3ms
# Speed: 1.0ms preprocess, 30.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 30.2ms
# Speed: 1.3ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.8ms
# Speed: 1.1ms preprocess, 29.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 33.5ms
# Speed: 1.1ms preprocess, 33.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.7ms
# Speed: 1.6ms preprocess, 29.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 cars, 1 truck, 1 bird, 30.6ms
# Speed: 1.1ms preprocess, 30.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 32.2ms
# Speed: 1.2ms preprocess, 32.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 cars, 1 truck, 1 bird, 29.9ms
# Speed: 1.3ms preprocess, 29.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 cars, 1 truck, 1 bird, 46.9ms
# Speed: 1.2ms preprocess, 46.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 cars, 1 truck, 1 bird, 29.9ms
# Speed: 1.1ms preprocess, 29.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 cars, 1 truck, 1 bird, 30.2ms
# Speed: 1.3ms preprocess, 30.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 cars, 1 truck, 1 bird, 30.1ms
# Speed: 1.1ms preprocess, 30.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 cars, 1 truck, 1 bird, 30.4ms
# Speed: 1.1ms preprocess, 30.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 cars, 1 truck, 1 bird, 29.6ms
# Speed: 1.2ms preprocess, 29.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 cars, 1 truck, 1 bird, 29.4ms
# Speed: 1.2ms preprocess, 29.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 cars, 1 truck, 1 bird, 29.4ms
# Speed: 1.2ms preprocess, 29.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 cars, 1 truck, 1 bird, 30.5ms
# Speed: 1.1ms preprocess, 30.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 2 trucks, 1 bird, 29.1ms
# Speed: 1.0ms preprocess, 29.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 2 trucks, 1 bird, 30.3ms
# Speed: 1.1ms preprocess, 30.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 3 trucks, 1 bird, 30.2ms
# Speed: 1.1ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 trucks, 1 bird, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 2 trucks, 1 bird, 29.9ms
# Speed: 1.1ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 2 trucks, 1 bird, 30.8ms
# Speed: 1.1ms preprocess, 30.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 2 trucks, 1 bird, 29.9ms
# Speed: 1.0ms preprocess, 29.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 car, 2 trucks, 1 bird, 29.7ms
# Speed: 1.5ms preprocess, 29.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 2 trucks, 1 bird, 29.1ms
# Speed: 1.1ms preprocess, 29.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 trucks, 1 bird, 31.3ms
# Speed: 1.0ms preprocess, 31.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 trucks, 1 bird, 45.1ms
# Speed: 1.3ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 trucks, 1 bird, 29.4ms
# Speed: 1.2ms preprocess, 29.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 trucks, 1 bird, 29.1ms
# Speed: 1.3ms preprocess, 29.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 trucks, 1 bird, 30.2ms
# Speed: 1.0ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 trucks, 1 bird, 30.8ms
# Speed: 1.3ms preprocess, 30.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 trucks, 1 bird, 29.8ms
# Speed: 1.0ms preprocess, 29.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 trucks, 1 bird, 29.4ms
# Speed: 1.1ms preprocess, 29.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 trucks, 1 bird, 29.6ms
# Speed: 1.2ms preprocess, 29.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 trucks, 1 bird, 30.7ms
# Speed: 1.1ms preprocess, 30.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 30.7ms
# Speed: 1.1ms preprocess, 30.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 31.2ms
# Speed: 1.3ms preprocess, 31.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 30.4ms
# Speed: 1.4ms preprocess, 30.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 30.9ms
# Speed: 1.1ms preprocess, 30.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.5ms
# Speed: 1.1ms preprocess, 29.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 30.2ms
# Speed: 1.0ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 32.4ms
# Speed: 1.1ms preprocess, 32.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.8ms
# Speed: 1.3ms preprocess, 29.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.9ms
# Speed: 1.2ms preprocess, 29.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.6ms
# Speed: 1.3ms preprocess, 29.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 39.1ms
# Speed: 1.6ms preprocess, 39.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 29.1ms
# Speed: 1.1ms preprocess, 29.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 car, 1 truck, 1 bird, 30.8ms
# Speed: 1.1ms preprocess, 30.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No frames grabbed!
# -1

# %% [markdown]
# <b>Exercise 2.2. [20 Points]</b>
#
# <b>Question</b>
# <ul>
# <li>What is the difference between Optical Flow and YOLO?</li>
# </ul>

# %% [markdown]
# The explanation goes here:

# %% [markdown]
# Optical Flow tracks the motion of objects in a video, i.e. in consecutive image frames, whereas YOLO is an object detection algorithm that detects objects in images or videos. Optical Flow focuses on the motion of objects, while YOLO focuses on detecting objects in images or videos. If we concatenate the outputs of YOLO, it seems as if we are tracking the objects, but in reality, we are detecting them in each frame separately.
